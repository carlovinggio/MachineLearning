# %% [markdown]
# Overview
# We are trying to find a relation between some crimes and the house price
#
# We are gonna use the next features
# - Thefts
# - Datetime
#
# files structure:
#
# crimes.csv
# datetime,state,total_robos,total_lesiones,total_homicidios,delitos_patrimoniales,secuestro,violacion,otros_delitos
#
# f.e.
# 2013-01-01,5943,1593,261,1971,134,128,4177
#
#
# properties-sell.csv
# created_on,operation,property_type,place_name,place_with_parent_names,geonames_id,lat-lon,lat,lon,price,currency,price_aprox_local_currency,price_aprox_usd,surface_total_in_m2,surface_covered_in_m2,price_usd_per_m2,price_per_m2,floor,rooms,expenses,properati_url,description,title,image_thumbnail
#
# f.e.
# 2013-09-19,sell,apartment,Nuevo Centro Urbano,|México|Quintana Roo|Solidaridad|Playa del Carmen|Nuevo Centro Urbano|,,\"20.627527,-87.076686\",20.627527,-87.076686,269000.0,USD,5059486.5,269000.0,110,110,2445.4545454545455,2445.4545454545455,,,,http://nuevo-centro-urbano.properati.com.mx/o6_venta_apartamento_nuevo-centro-urbano,\"Referencia #28010. En el centro de Playa del Carmen, lo corazón de la Riviera Maya, Villa Amalfi un condominio de lujo, con departamentos de 3 recamaras y 3 baños, con cocina equipada, sala, comedor, aire acondicionado en todos ambientes y una amplia terraza accesible desde los dormitorios. Este hermoso y moderno departamento está situado a sólo cuatro cuadras de la playa y 3 cuadras de la famosa 5ª Avenida. El condominio es espacioso y abierto para disfrutar de unas relajantes vacaciones en el centro emocionante de Playa del Carmen. Disfrutar de las vistas desde la piscina de la azotea enorme y cubierta de sol mientras disfruta de las refrescantes brisas del Caribe. Entretener a los amigos y familiares con el jacuzzi y hacer una parrillada en la zona de barbacoa. Este complejo cuenta con ventanas de doble acristalamiento de vidrio y deslizadores, bonitas terrazas, acceso a ascensor, bodegas, estacionamiento subterráneo. El estilo y la ubicación de estos departamentos sin duda captará la atención de todos.\",Departamento en Venta. Ref. #28010. 3 Dormitorios. 110 m2. Departamento Villa Amalfi.  en Playa del Carmen,https://thumbs-cf.properati.com/3/q4Ws9xQT8Yu37ZlyI3zM02GjkwE=/trim/198x0/smart/filters:strip_icc()/www.inmokey.com/files/c-2507/properties/4/7/4708f352bc5c111297681e366047dc96.jpg"
#
# y = house pricing

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns

import os

# %%
path = os.getcwd()
print(path)
properties_sell_chunks = pd.read_csv(r"Files\properati-MX-2016-11-01-properties-sell.csv", chunksize=1000)
properties_rent_chunks = pd.read_csv(r"Files\properati-MX-2016-11-01-properties-rent.csv", chunksize=1000)
# chunks = properties_sell_chunks.get_chunk(1000)
# print(chunks.head())
properties_sell_df_chunk = next(properties_sell_chunks)
properties_rent_df_chunk = next(properties_rent_chunks)
properties_rent_df_chunk.head()
# Out:
# c:\Users\carlo\MachineLearning\test ML
#    created_on operation property_type           place_name  \
# 0  2013-09-19      rent         house     Playa del Carmen
# 1  2013-09-19      rent     apartment  Nuevo Centro Urbano
# 2  2013-09-19      rent     apartment  Nuevo Centro Urbano
# 3  2013-09-19      rent     apartment  Nuevo Centro Urbano
# 4  2013-09-19      rent         store     Playa del Carmen
#
#                              place_with_parent_names  geonames_id  \
# 0  |México|Quintana Roo|Solidaridad|Playa del Car...          NaN
# 1  |México|Quintana Roo|Solidaridad|Playa del Car...          NaN
# 2  |México|Quintana Roo|Solidaridad|Playa del Car...          NaN
# 3  |México|Quintana Roo|Solidaridad|Playa del Car...          NaN
# 4  |México|Quintana Roo|Solidaridad|Playa del Car...          NaN
#
#                 lat-lon        lat        lon    price  ...  \
# 0  20.612709,-87.102987  20.612709 -87.102987      NaN  ...
# 1  20.626679,-87.075944  20.626679 -87.075944   2200.0  ...
# 2  20.626729,-87.075858  20.626729 -87.075858  19000.0  ...
# 3  20.630104,-87.072484  20.630104 -87.072484  10000.0  ...
# 4  20.635424,-87.077995  20.635424 -87.077995  30000.0  ...
#
#   surface_covered_in_m2  price_usd_per_m2  price_per_m2  floor  rooms  \
# 0                 250.0               NaN           NaN    NaN    NaN
# 1                 110.0         20.000000     20.000000    NaN    NaN
# 2                 110.0         11.380818    172.727273    NaN    NaN
# 3                  65.0         10.136769    153.846154    NaN    NaN
# 4                 250.0          7.906680    120.000000    NaN    NaN
#
#    expenses                                      properati_url  \
# 0       NaN  http://playa-del-carmen-playa-del-carmen.prope...
# 1       NaN  http://nuevo-centro-urbano.properati.com.mx/o4...
# 2       NaN  http://nuevo-centro-urbano.properati.com.mx/o5...
# 3       NaN  http://nuevo-centro-urbano.properati.com.mx/ob...
# 4       NaN  http://playa-del-carmen-playa-del-carmen.prope...
#
#                                          description  \
# 0  Referencia #55546. Hermosa casa en el barrio C...
# 1  Referencia #27985. Ático completamente amuebla...
# 2  Referencia #27996. Departamento completamente ...
# 3  Referencia #29065. Departamento perfecto para ...
# 4  Referencia #29386. Ubicado en uno de los princ...
#
#                                                title  \
# 0  Casa en Alquiler. Ref. #55546. 3 Dormitorios. ...
# 1  Departamento en Alquiler. Ref. #27985. 2 Dormi...
# 2  Departamento en Alquiler. Ref. #27996. 2 Dormi...
# 3  Departamento en Alquiler. Ref. #29065. 1 Dormi...
# 4  Local en Alquiler. Ref. #29386. 250 m2. Local ...
#
#                                      image_thumbnail
# 0  https://thumbs-cf.properati.com/1/dLISoi0WStzf...
# 1  https://thumbs-cf.properati.com/9/-DZ0FUVqgAnA...
# 2  https://thumbs-cf.properati.com/4/dyZjLPbRTuui...
# 3  https://thumbs-cf.properati.com/0/2tp0o2qIaZia...
# 4  https://thumbs-cf.properati.com/2/5L2Y9_OYAxNL...
#
# [5 rows x 24 columns]

# %%
# include new column with the state name
locations_data = pd.DataFrame()

locations_data[['_','country', 'state', 'municipality', 'city', 'neighborhood','__']] = properties_sell_df_chunk["place_with_parent_names"].str.split("|", expand=True)
locations_data.drop(columns=['_','__'], inplace=True)
# _, country, state, municipality, city, neighborhood, __ = locations_data
# print(locations_data[country])
# rint(locations_data.head())
# properties_sell_df_chunk[['country', 'state', 'municipality', 'city', 'neighborhood']] =  locations_data[[country, state, municipality, city, neighborhood]]
properties_sell_df_chunk[['country', 'state', 'municipality', 'city', 'neighborhood']] = locations_data[['country', 'state', 'municipality', 'city', 'neighborhood']]

# %%
properties_sell_df_chunk
# Out:
#      created_on operation property_type           place_name  \
# 0    2013-09-19      sell     apartment  Nuevo Centro Urbano
# 1    2013-09-19      sell     apartment  Nuevo Centro Urbano
# 2    2013-09-19      sell     apartment  Nuevo Centro Urbano
# 3    2013-09-19      sell     apartment     Playa del Carmen
# 4    2013-09-19      sell     apartment  Nuevo Centro Urbano
# ..          ...       ...           ...                  ...
# 995  2015-03-31      sell         house            Querétaro
# 996  2015-03-31      sell         house            Querétaro
# 997  2015-03-31      sell         house               Mérida
# 998  2015-03-31      sell         house    Villa de Zaachila
# 999  2015-03-31      sell         house            Michoacán
#
#                                place_with_parent_names  geonames_id  \
# 0    |México|Quintana Roo|Solidaridad|Playa del Car...          NaN
# 1    |México|Quintana Roo|Solidaridad|Playa del Car...          NaN
# 2    |México|Quintana Roo|Solidaridad|Playa del Car...          NaN
# 3    |México|Quintana Roo|Solidaridad|Playa del Car...          NaN
# 4    |México|Quintana Roo|Solidaridad|Playa del Car...          NaN
# ..                                                 ...          ...
# 995                       |México|Querétaro|Querétaro|          NaN
# 996                       |México|Querétaro|Querétaro|          NaN
# 997                            |México|Yucatán|Mérida|          NaN
# 998                  |México|Oaxaca|Villa de Zaachila|          NaN
# 999              |México|Chiapas|Jiquipilas|Michoacán|          NaN
#
#                    lat-lon        lat         lon      price  ... expenses  \
# 0     20.627527,-87.076686  20.627527  -87.076686   269000.0  ...      NaN
# 1     20.627567,-87.076718  20.627567  -87.076718   230000.0  ...      NaN
# 2       20.6267,-87.075866  20.626700  -87.075866   135000.0  ...      NaN
# 3     20.635482,-87.070345  20.635482  -87.070345   185000.0  ...      NaN
# 4     20.629092,-87.074658  20.629092  -87.074658   180000.0  ...      NaN
# ..                     ...        ...         ...        ...  ...      ...
# 995  20.740651,-100.468721  20.740651 -100.468721  1600000.0  ...      NaN
# 996  20.740691,-100.468721  20.740691 -100.468721  1600000.0  ...      NaN
# 997   20.968147,-89.629875  20.968147  -89.629875  3510000.0  ...      NaN
# 998                    NaN        NaN         NaN   549000.0  ...      NaN
# 999  19.708853,-101.166695  19.708853 -101.166695  3000000.0  ...      NaN
#
#                                          properati_url  \
# 0    http://nuevo-centro-urbano.properati.com.mx/o6...
# 1    http://nuevo-centro-urbano.properati.com.mx/o8...
# 2    http://nuevo-centro-urbano.properati.com.mx/o9...
# 3    http://playa-del-carmen-playa-del-carmen.prope...
# 4    http://nuevo-centro-urbano.properati.com.mx/ok...
# ..                                                 ...
# 995  http://queretaro-queretaro.properati.com.mx/4l...
# 996  http://queretaro-queretaro.properati.com.mx/4l...
# 997  http://merida-yucatan.properati.com.mx/4m6y_ve...
# 998  http://villa-de-zaachila.properati.com.mx/4m7c...
# 999  http://michoacan-jiquipilas.properati.com.mx/4...
#
#                                            description  \
# 0    Referencia #28010. En el centro de Playa del C...
# 1    Referencia #28925. En el centro de Playa del C...
# 2    Referencia #29031. La Papaya un proyecto altam...
# 3    Referencia #29032. Visite las nuevas Acqua Ter...
# 4    Referencia #33970. Todavía tenemos algunas uni...
# ..                                                 ...
# 995  Nocnok ID: MX14-AW3863. Casa con gran calidad ...
# 996  Nocnok ID: MX14-AW3874. Casa con gran calidad ...
# 997  Nocnok ID: MX15-BA3804. CÓDIGO WCP-3986<br><br...
# 998  Nocnok ID: MX15-BA3825. ECONÓMICA CASA EN FRAC...
# 999  Nocnok ID: MX15-BA4018. Casa en buena ubicació...
#
#                                                  title  \
# 0    Departamento en Venta. Ref. #28010. 3 Dormitor...
# 1    Departamento en Venta. Ref. #28925. 3 Dormitor...
# 2    Departamento en Venta. Ref. #29031. 1 Dormitor...
# 3    Departamento en Venta. Ref. #29032. 2 Dormitor...
# 4    Departamento en Venta. Ref. #33970. Encanto Ri...
# ..                                                 ...
# 995             Casa en Venta en San Isidro Juriquilla
# 996             Casa en Venta en San Isidro Juriquilla
# 997                   Casa en Venta en Barrio Mejorada
# 998    Casa en Venta en Fracc. Real del Valle Zaachila
# 999                    Casa en Venta en Ventura Puente
#
#                                        image_thumbnail  country         state  \
# 0    https://thumbs-cf.properati.com/3/q4Ws9xQT8Yu3...   México  Quintana Roo
# 1    https://thumbs-cf.properati.com/8/7W4OI5hIXPdY...   México  Quintana Roo
# 2    https://thumbs-cf.properati.com/0/4h1_ZbVNWly0...   México  Quintana Roo
# 3    https://thumbs-cf.properati.com/0/Mxv1JulyoQBM...   México  Quintana Roo
# 4    https://thumbs-cf.properati.com/9/jzkZFLJUFVEw...   México  Quintana Roo
# ..                                                 ...      ...           ...
# 995  https://thumbs-cf.properati.com/4/zdIiILdIUA-l...   México     Querétaro
# 996  https://thumbs-cf.properati.com/2/RCgn5-CCJ2zz...   México     Querétaro
# 997  https://thumbs-cf.properati.com/6/uemnuHp7GvkY...   México       Yucatán
# 998  https://thumbs-cf.properati.com/2/3-1vgFn_miND...   México        Oaxaca
# 999  https://thumbs-cf.properati.com/9/4RQyAFgKUARS...   México       Chiapas
#
#           municipality              city         neighborhood
# 0          Solidaridad  Playa del Carmen  Nuevo Centro Urbano
# 1          Solidaridad  Playa del Carmen  Nuevo Centro Urbano
# 2          Solidaridad  Playa del Carmen  Nuevo Centro Urbano
# 3          Solidaridad  Playa del Carmen     Playa del Carmen
# 4          Solidaridad  Playa del Carmen  Nuevo Centro Urbano
# ..                 ...               ...                  ...
# 995          Querétaro                                   None
# 996          Querétaro                                   None
# 997             Mérida                                   None
# 998  Villa de Zaachila                                   None
# 999         Jiquipilas         Michoacán
#
# [1000 rows x 29 columns]

# %% [markdown]
# ## Preparing the datasets
#
# Cleaning, organizing and preparing the datasets.
#
# ## Visualization
#
# This section includes all the visualizations and plots

# %%
crimes_df = pd.read_csv('Files/crimes_by_state.csv')
thefts_summed = crimes_df['thefts']
sns.histplot(data=crimes_df, x="thefts")

# sns.catplot(data=crimes_df, x="state", y="thefts", hue="state")

# %% [markdown]
# ## Outcomes
# TODO: From the big df, obtain another that contains only the important values i.e state1 = avg selling price
